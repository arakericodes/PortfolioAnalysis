# %%
import pandas as pd 
import seaborn as sns

# %%
df = pd.read_csv("Portfolio_prices.csv")

# %%
df
# Out:
#              Date Ticker        Open        High         Low       Close  \
# 0      2020-01-03    JPM  137.500000  139.229996  137.080002  138.339996
# 1      2020-01-03     KO   54.320000   54.990002   54.090000   54.689999
# 2      2020-01-03    LMT  404.019989  417.170013  403.000000  413.739990
# 3      2020-01-03     MS   51.220001   51.450001   50.830002   51.200001
# 4      2020-01-03   MSCI  262.200012  263.579987  259.269989  260.750000
# ...           ...    ...         ...         ...         ...         ...
# 35392  2025-03-21   ADAP    0.307000    0.310000    0.280000    0.291000
# 35393  2025-03-21   AAPL  211.559998  218.839996  211.279999  218.270004
# 35394  2025-03-21    SPY  559.280029  564.890015  558.030029  563.979980
# 35395  2025-03-21    HUM  266.140015  269.309998  263.230011  266.170013
# 35396  2025-03-21   TMUS  254.440002  258.440002  254.330002  255.839996
#
#          Adjusted   Returns    Volume
# 0      119.874138 -0.013197  10386800
# ...

# %%
sns.kdeplot(df['Returns'])
# Out:
# <Axes: xlabel='Returns', ylabel='Density'>
